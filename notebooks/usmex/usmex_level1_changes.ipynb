# %% [markdown]
# # Comparing Changes
#
# ### US/Mexico level 1 - states

# %%
import geopandas as gpd
import pandas as pd

# %%
df = gpd.read_parquet("../geoplanar/datasets/usmex/usmex_1.parquet")

# %%
df2 = gpd.read_parquet("../geoplanar/datasets/usmex/final_usmex1.parquet")

# %% [markdown]
# ## Changes in Centroids

# %%
old_cen = df.centroid
old_cen.head()
# Out:
# /Users/ecv/anaconda3/envs/geoplanar_docs/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# 0    POINT (-102.36194 22.00644)
# 1    POINT (-115.09356 30.55562)
# 2    POINT (-112.04916 25.92125)
# 3     POINT (-90.31599 18.84861)
# 4     POINT (-92.46324 16.48400)
# dtype: geometry

# %%
new_cen = df2.centroid
new_cen.head()
# Out:
# /Users/ecv/anaconda3/envs/geoplanar_docs/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.
# 0    POINT (-102.36194 22.00644)
# 1    POINT (-115.09356 30.55562)
# 2    POINT (-112.04916 25.92125)
# 3     POINT (-90.31599 18.84861)
# 4     POINT (-92.46324 16.48400)
# dtype: geometry

# %%
print(old_cen.iloc[73]) # old texas centroid
# Out:
# POINT (-99.3579843873821 31.49105418038344)

# %%
print(new_cen.iloc[73]) # new texas centroid
# Out:
# POINT (-99.35809086426373 31.49128364985037)

# %%
base = df2.geometry.boundary.plot(edgecolor='grey', figsize=(9, 9))
old_cen.plot(ax=base, color='red')
new_cen.plot(ax=base, color='blue')
# Out:
# <AxesSubplot:>

# %%
import folium
# old centroids
m = old_cen.explore(
     color='red',
     tiles="CartoDB positron", # use "CartoDB positron" tiles
     name = 'Old Centroids'
)

# new centroids
new_cen.explore(
     m=m, # pass the map object
     color='blue',
     tooltip=False,
     name = 'New Centroids'
)

folium.LayerControl().add_to(m)  # layer control

m # execute the map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_32e058c0676749eebe47a0bf7d37586a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Comparing old and new centroids
# We will use the different geom comparsions that GeoPandas has to spot the differences in centroids

# %%
# geom_equals
df2['equals'] = old_cen.geom_equals(new_cen, align=False) 

# geom_almost_equals with 5 decimals
df2['almost_equals'] = old_cen.geom_almost_equals(new_cen, decimal=5)

#  geom_almost_equals with all of centroid decimals
df2['almost_equals_full'] = old_cen.geom_almost_equals(new_cen, decimal=14)

# geom_equals_exact with .00001 tolerance
df2['equals_exact'] = old_cen.geom_equals_exact(new_cen, tolerance=.00001, align=False)

# %%
df2
# Out:
#     index              ADM1_ES ADM1_PCODE ADM1_REF ADM1ALT1ES ADM1ALT2ES  \
# 0       0       Aguascalientes       MX01     None       None       None
# 1       1      Baja California       MX02     None       None       None
# 2       2  Baja California Sur       MX03     None       None       None
# 3       3             Campeche       MX04     None       None       None
# 4       4              Chiapas       MX07     None       None       None
# ..    ...                  ...        ...      ...        ...        ...
# 76     46                 None       None     None       None       None
# 77     47                 None       None     None       None       None
# 78     48                 None       None     None       None       None
# 79     49                 None       None     None       None       None
# 80     50                 None       None     None       None       None
#
#    ADM0_ES ADM0_PCODE        date     validOn  ... VARNAME_1  NL_NAME_1  \
# 0   México         MX  2020-06-23  2021-06-18  ...      None       None
# 1   México         MX  2020-06-23  2021-06-18  ...      None       None
# 2   México         MX  2020-06-23  2021-06-18  ...      None       None
# 3   México         MX  2020-06-23  2021-06-18  ...      None       None
# 4   México         MX  2020-06-23  2021-06-18  ...      None       None
# ..     ...        ...         ...         ...  ...       ...        ...
# 76    None       None        None        None  ...        VA       None
# 77    None       None        None        None  ...  WA|Wash.       None
# 78    None       None        None        None  ...  WV|W.Va.       None
# 79    None       None        None        None  ...   WI|Wis.       None
# 80    None       None        None        None  ...   WY|Wyo.       None
#
#     TYPE_1 ENGTYPE_1  CC_1 HASC_1 equals almost_equals almost_equals_full  \
# 0     None      None  None   None   True          True               True
# 1     None      None  None   None  False          True              False
# 2     None      None  None   None   True          True               True
# 3     None      None  None   None  False          True              False
# 4     None      None  None   None  False          True              False
# ..     ...       ...   ...    ...    ...           ...                ...
# 76   State     State  None  US.VA  False          True              False
# 77   State     State  None  US.WA   True          True               True
# 78   State     State  None  US.WV  False          True              False
# 79   State     State  None  US.WI  False          True              False
# 80   State     State  None  US.WY  False          True              False
#
#    equals_exact
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ..          ...
# 76         True
# 77         True
# 78         True
# 79         True
# 80         True
#
# [81 rows x 29 columns]

# %%
df2.groupby(['equals']).size()
# Out:
# equals
# False    63
# True     18
# dtype: int64

# %%
df2.loc[df2['equals'] == False] # all states that changed based on geom_equals
# Out:
#     index               ADM1_ES ADM1_PCODE ADM1_REF ADM1ALT1ES ADM1ALT2ES  \
# 1       1       Baja California       MX02     None       None       None
# 3       3              Campeche       MX04     None       None       None
# 4       4               Chiapas       MX07     None       None       None
# 5       5             Chihuahua       MX08     None       None       None
# 6       6  Coahuila de Zaragoza       MX05     None       None       None
# ..    ...                   ...        ...      ...        ...        ...
# 75     45                  None       None     None       None       None
# 76     46                  None       None     None       None       None
# 78     48                  None       None     None       None       None
# 79     49                  None       None     None       None       None
# 80     50                  None       None     None       None       None
#
#    ADM0_ES ADM0_PCODE        date     validOn  ... VARNAME_1  NL_NAME_1  \
# 1   México         MX  2020-06-23  2021-06-18  ...      None       None
# 3   México         MX  2020-06-23  2021-06-18  ...      None       None
# 4   México         MX  2020-06-23  2021-06-18  ...      None       None
# 5   México         MX  2020-06-23  2021-06-18  ...      None       None
# 6   México         MX  2020-06-23  2021-06-18  ...      None       None
# ..     ...        ...         ...         ...  ...       ...        ...
# 75    None       None        None        None  ...        VT       None
# 76    None       None        None        None  ...        VA       None
# 78    None       None        None        None  ...  WV|W.Va.       None
# 79    None       None        None        None  ...   WI|Wis.       None
# 80    None       None        None        None  ...   WY|Wyo.       None
#
#     TYPE_1 ENGTYPE_1  CC_1 HASC_1 equals almost_equals almost_equals_full  \
# 1     None      None  None   None  False          True              False
# 3     None      None  None   None  False          True              False
# 4     None      None  None   None  False          True              False
# 5     None      None  None   None  False          True              False
# 6     None      None  None   None  False          True              False
# ..     ...       ...   ...    ...    ...           ...                ...
# 75   State     State  None  US.VT  False          True              False
# 76   State     State  None  US.VA  False          True              False
# 78   State     State  None  US.WV  False          True              False
# 79   State     State  None  US.WI  False          True              False
# 80   State     State  None  US.WY  False          True              False
#
#    equals_exact
# 1          True
# 3          True
# 4          True
# 5          True
# 6          True
# ..          ...
# 75         True
# 76         True
# 78         True
# 79         True
# 80         True
#
# [63 rows x 29 columns]

# %%
df2.groupby(['almost_equals']).size()
# Out:
# almost_equals
# False     3
# True     78
# dtype: int64

# %%
df2.groupby(['almost_equals_full']).size()
# Out:
# almost_equals_full
# False    63
# True     18
# dtype: int64

# %%
df2.groupby(['equals_exact']).size()
# Out:
# equals_exact
# False     3
# True     78
# dtype: int64

# %% [markdown]
# ## Changes in Area
#
# need to:
# 1. check all areas before and after
# 2. compare /contrast
# 3. explicitly state which ones changed

# %%
old_area = df
new_area = df2

# %%
old_area.to_crs(3857)
new_area.to_crs(3857)
# Out:
#     index              ADM1_ES ADM1_PCODE ADM1_REF ADM1ALT1ES ADM1ALT2ES  \
# 0       0       Aguascalientes       MX01     None       None       None
# 1       1      Baja California       MX02     None       None       None
# 2       2  Baja California Sur       MX03     None       None       None
# 3       3             Campeche       MX04     None       None       None
# 4       4              Chiapas       MX07     None       None       None
# ..    ...                  ...        ...      ...        ...        ...
# 76     46                 None       None     None       None       None
# 77     47                 None       None     None       None       None
# 78     48                 None       None     None       None       None
# 79     49                 None       None     None       None       None
# 80     50                 None       None     None       None       None
#
#    ADM0_ES ADM0_PCODE        date     validOn  ... VARNAME_1  NL_NAME_1  \
# 0   México         MX  2020-06-23  2021-06-18  ...      None       None
# 1   México         MX  2020-06-23  2021-06-18  ...      None       None
# 2   México         MX  2020-06-23  2021-06-18  ...      None       None
# 3   México         MX  2020-06-23  2021-06-18  ...      None       None
# 4   México         MX  2020-06-23  2021-06-18  ...      None       None
# ..     ...        ...         ...         ...  ...       ...        ...
# 76    None       None        None        None  ...        VA       None
# 77    None       None        None        None  ...  WA|Wash.       None
# 78    None       None        None        None  ...  WV|W.Va.       None
# 79    None       None        None        None  ...   WI|Wis.       None
# 80    None       None        None        None  ...   WY|Wyo.       None
#
#     TYPE_1 ENGTYPE_1  CC_1 HASC_1 equals almost_equals almost_equals_full  \
# 0     None      None  None   None   True          True               True
# 1     None      None  None   None  False          True              False
# 2     None      None  None   None   True          True               True
# 3     None      None  None   None  False          True              False
# 4     None      None  None   None  False          True              False
# ..     ...       ...   ...    ...    ...           ...                ...
# 76   State     State  None  US.VA  False          True              False
# 77   State     State  None  US.WA   True          True               True
# 78   State     State  None  US.WV  False          True              False
# 79   State     State  None  US.WI  False          True              False
# 80   State     State  None  US.WY  False          True              False
#
#    equals_exact
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ..          ...
# 76         True
# 77         True
# 78         True
# 79         True
# 80         True
#
# [81 rows x 29 columns]

# %%
old_area ["area"] = old_area['geometry'].area
# Out:
# /Users/ecv/anaconda3/envs/geoplanar_docs/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
print(old_area.area)
# Out:
# 0      0.491151
# 1      6.851318
# 2      6.486020
# 3      4.757845
# 4      6.150488
#         ...
# 76    10.574154
# 77    20.832837
# 78     6.487066
# 79    19.206545
# 80    27.967967
# Length: 81, dtype: float64
# /Users/ecv/anaconda3/envs/geoplanar_docs/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
new_area ["area"] = new_area['geometry'].area
# Out:
# /Users/ecv/anaconda3/envs/geoplanar_docs/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
print(new_area.area)
# Out:
# 0      0.491151
# 1      6.851318
# 2      6.486020
# 3      4.757845
# 4      6.150488
#         ...
# 76    10.574154
# 77    20.832837
# 78     6.487066
# 79    19.206545
# 80    27.967967
# Length: 81, dtype: float64
# /Users/ecv/anaconda3/envs/geoplanar_docs/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   """Entry point for launching an IPython kernel.

# %%
new_area['area'].isin(old_area['area']).value_counts()
# Out:
# False    62
# True     19
# Name: area, dtype: int64

# %%
old_area.iloc[73].area # old texas area
# Out:
# 65.18626120769625

# %%
new_area.iloc[73].area # new texas area
# Out:
# 65.18255836373686

# %%
old_area.iloc[4].area # old Chiapas area
# Out:
# 6.150488283875262

# %%
new_area.iloc[4].area # new Chiapas area
# Out:
# 6.150488283875289

# %%
old_area.iloc[0].area # old Aguascalientes area
# Out:
# 0.49115145173002794

# %%
new_area.iloc[0].area # new Aguascalientes area
# Out:
# 0.49115145173002794

# %%
old_area.iloc[15].area # old Michoacan area
# Out:
# 5.03313817830897

# %%
new_area.iloc[15].area # new Michoacan area
# Out:
# 5.033138178309004
